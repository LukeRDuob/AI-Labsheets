# %% [markdown]
# <a href="https://colab.research.google.com/github/LukeRDuob/AI-Labsheets/blob/main/Coursework_sectionB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Section B

# %% [markdown]
# In this section, you will work with pretrained neural network backbones
# and adapt them for the CIFAR-10 classification task. You are required to load one pretrained
# CNN model and one pretrained Transformer-based vision model, modify their classification
# heads to output 10 logits, and verify that both models can successfully process
# CIFAR-10-shaped inputs through a dummy forward pass.

# %% [markdown]
# (Q4) Load a pretrained CNN backbone. Load a pretrained ResNet-18 model from timm, and
# initialise it using the pretrained weights. (4 marks)
