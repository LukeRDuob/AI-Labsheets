# %% [markdown]
# <a href="https://colab.research.google.com/github/LukeRDuob/AI-Labsheets/blob/main/Coursework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AMA Coursework

# %% [markdown]
# ### Section A

# %% [markdown]
# Q1

# %%
from torchvision.datasets import CIFAR10
import torchvision.transforms as transforms
import torch as t

# Define transformations (normalize images to tensors)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
# Store training and testing datasets
train_dataset = CIFAR10('./data', train=True, download=True, transform=transform)
test_dataset = CIFAR10('./data', train=False, download=True, transform=transform)
# Out:
# <class 'tuple'>
